# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = '../data/initial_struct_vertex_material.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    VertexIndex        X        Y        Z Material
# 0            0 -616.005 -325.887  304.214  Polymer
# 1            1 -597.828 -322.434  303.985  Polymer
# 2            2 -615.747 -305.498  303.996  Polymer
# 3            3 -615.767 -339.997  304.151  Polymer
# 4            4 -568.076 -326.674  304.038  Polymer

# %%
fig = plt.figure(figsize=(12, 9))
ax = fig.add_subplot(projection='3d')

for grp_name, grp_idx in df.groupby('Material').groups.items():
    y = df.iloc[grp_idx,2]
    x = df.iloc[grp_idx,1]
    z = df.iloc[grp_idx,3]
    ax.scatter(x, y, z, label=grp_name)

ax.legend(bbox_to_anchor=(1, 0.5), loc='center left', frameon=False)
plt.show()

# %%
df.groupby(['Material'])['Z'].apply(lambda x: x.max() - x.min()).reset_index()
# Out:
#        Material        Z
# 0       Polymer   53.168
# 1   Si3N4_LPCVD   87.424
# 2    SiO2_PECVD   60.230
# 3  SiO2_Thermal    0.256
# 4     Si_Amorph   37.191
# 5       Si_Xtal  400.094

# %%
df.groupby(['Material'])['Z'].max().reset_index()
# Out:
#        Material        Z
# 0       Polymer  357.153
# 1   Si3N4_LPCVD  298.997
# 2    SiO2_PECVD  460.183
# 3  SiO2_Thermal  204.027
# 4     Si_Amorph  401.171
# 5       Si_Xtal  200.044

# %%
df.groupby(['Material'])['Z'].min().reset_index()
# Out:
#        Material        Z
# 0       Polymer  303.985
# 1   Si3N4_LPCVD  211.573
# 2    SiO2_PECVD  399.953
# 3  SiO2_Thermal  203.771
# 4     Si_Amorph  363.980
# 5       Si_Xtal -200.050

# %%
path = '../checking.csv'
df = pd.read_csv(path)
fig = plt.figure(figsize=(12, 9))
ax = fig.add_subplot(projection='3d')

for grp_name, grp_idx in df.groupby('material').groups.items():
    y = df.iloc[grp_idx,1]
    x = df.iloc[grp_idx,0]
    z = df.iloc[grp_idx,2]
    ax.scatter(x, y, z, label=grp_name)

ax.legend(bbox_to_anchor=(1, 0.5), loc='center left', frameon=False)
plt.show()
